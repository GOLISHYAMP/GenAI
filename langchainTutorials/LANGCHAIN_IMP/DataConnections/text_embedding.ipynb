# %%
from langchain_ollama.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings(model= "llama3.2:1b")

# %%
embed = embeddings.embed_query("hello shyam, how are you?")
print(len(embed))  #2048 embedding length for each sentence
# Out:
# 2048

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
loader = CSVLoader("some_data\\penguins.csv")
data = loader.load()

# %%
print(data[0].page_content)
# Out:
# species: Adelie
# island: Torgersen
# bill_length_mm: 39.1
# bill_depth_mm: 18.7
# flipper_length_mm: 181
# body_mass_g: 3750
# sex: MALE

# %%
len(data)
# Out:
# 342

# %%
# [embeddings.embed_query(record.page_content) for record in data]
embeddings.embed_query(data[0].page_content)
# Out:
# [-0.012952332,
#  0.06634533,
#  0.02117171,
#  0.016703485,
#  0.030237013,
#  -0.020038953,
#  -0.00809334,
#  0.014537691,
#  -0.010014398,
#  -0.0066412603,
#  -0.029767562,
#  0.020360118,
#  0.025109647,
#  -0.016234415,
#  -0.028347682,
#  -0.023849899,
#  0.0008405067,
#  -0.011356878,
#  -0.019927649,
#  0.013090384,
#  -0.013466641,
#  0.017845219,
#  -0.00027756533,
#  0.0009692767,
#  -0.018974926,
#  -0.044398095,
#  0.0056333854,
#  0.030245896,
#  -0.010913793,
#  -0.03248554,
#  -0.04017569,
#  0.014397764,
#  -0.016081907,
#  0.0028868113,
#  0.03120016,
#  -0.009505076,
#  -0.006120752,
#  -0.037006374,
#  0.010324302,
#  -0.022633243,
#  0.039915614,
#  0.0070566055,
#  -0.006025107,
#  -0.00878156,
#  0.0021720123,
#  0.002519363,
#  0.0047478024,
#  -0.0008053297,
#  0.0052572456,
#  0.020130144,
#  -0.02917088,
#  0.0070549888,
#  0.017178765,
#  0.020791873,
#  -0.010707937,
#  0.011133025,
#  0.0018392554,
#  -0.010442863,
#  -0.0077448105,
#  0.018001031,
# ...

# %%
embedded_docs = embeddings.embed_documents([record.page_content for record in data])

# %%
len(embedded_docs)
# Out:
# 342
